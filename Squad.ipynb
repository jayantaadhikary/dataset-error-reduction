# %% [markdown]
# ## SQuAD dataset - Crowdworkers posted questions

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
import openai
from dotenv import load_dotenv
import os

# %%
# Load environment variables from .env
load_dotenv()

openai_api_key = os.getenv("OPENAI_API_KEY")

openai.api_key = openai_api_key

# %%
dataset = load_dataset("squad")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 87599
#     })
#     validation: Dataset({
#         features: ['id', 'title', 'context', 'question', 'answers'],
#         num_rows: 10570
#     })
# })

# %%
dataset.shape
# Out:
# {'train': (87599, 5), 'validation': (10570, 5)}

# %%
# Pandas Dataframe 
df = pd.DataFrame(dataset['train'])

# %%
# Selecting 10 random rows from the dataframe
randomQuestions = df.sample(n=50)

# %%
randomQuestions.head()
# Out:
#                              id               title  \
# 82499  57312c4e497a881900248c0a        Qing_dynasty
# 41364  57290ee56aef051400154a04   States_of_Germany
# 83550  5731882fe6313a140071d049              Mosaic
# 52612  5726e7c5dd62a815002e94a0  Chinese_characters
# 41068  5726144d271a42140099d444            Clothing
#
#                                                  context  \
# 82499  Li Zicheng then led a coalition of rebel force...
# 41364  In 1952, following a referendum, Baden, Württe...
# 83550  The ban on figurative depiction was not taken ...
# 52612  The Shang dynasty oracle bone script and the Z...
# 41068  According to archaeologists and anthropologist...
#
#                                                 question  \
# 82499                        Who beat Li Zicheng's army?
# 41364  Which city did Baden, Württemberg-Baden, and W...
# 83550  What is the central figure doing in the mosaic...
# 52612  Who work in the style of carving a traditional...
# 41068  Where have flax fibers which may have been use...
#
#                                                  answers
# 82499  {'text': ['Wu and Dorgon'], 'answer_start': [6...
# 41364  {'text': ['Baden-Württemberg'], 'answer_start'...
# 83550  {'text': ['playing a lyre'], 'answer_start': [...
# 52612  {'text': ['calligraphers'], 'answer_start': [5...
# 41068  {'text': ['a prehistoric cave'], 'answer_start...

# %%
examplePrompt = """I want you to perform extractive question answering. I will send you an example that contains the context, question, and answer. The answer contains the answer and the start character index of the answer. 
Context: Conversely, most heat-treatable alloys are precipitation hardening alloys, which produce the opposite effects that steel does. When heated to form a solution and then cooled quickly, these alloys become much softer than normal, during the diffusionless transformation, and then harden as they age. The solutes in these alloys will precipitate over time, forming intermetallic phases, which are difficult to discern from the base metal. Unlike steel, in which the solid solution separates to form different crystal phases, precipitation hardening alloys separate to form different phases within the same crystal. These intermetallic alloys appear homogeneous in crystal structure, but tend to behave heterogeneous, becoming hard and somewhat brittle.
Question: What makes alloys more softer than normal?
Answer: {'text': ['When heated to form a solution and then cooled quickly'], 'answer_start': [127]}"""


result = openai.Completion.create(model="gpt-3.5-turbo-instruct", prompt=examplePrompt, max_tokens=100)

print(result['choices'][0]['text'])

# %%
result.choices[0].text
# Out:
# ''

# %%
# Using OpenAI Api to feed the questions into gpt 3.5 turbo model and get the answer from gpt.

def getGPTAnswers(row):
    question = row['question']
    context = row['context']
    
    prompt = f"Perform extractive question answering from the context. The answer should be in an array containing the answer and the start character index of the answer in format of {{'text': [], 'answer_start': []}}.\nContext: {context}\n\nQuestion: {question}\nAnswer:?"
    
    response = openai.Completion.create(model="gpt-3.5-turbo-instruct", prompt=prompt, max_tokens=100)
    
#   answer = response.choices[0].text.strip()
#   answer_start = context.find(answer)
    
#   return {'text': [answer], 'answer_start': [answer_start]}
    return response.choices[0].text.strip()

# %%
# Testing a single row before trying on the randomQuestion dataframe
testAnswer = getGPTAnswers(df.loc[0])

# %%
testAnswer
# Out:
# "{\n  'text': ['Saint Bernadette Soubirous'],\n  'answer_start': [255]\n}"

# %%
# adding the GPT Answers to the randomQuestions dataframe

randomQuestions['gpt_3.5_answers'] = randomQuestions.apply(getGPTAnswers, axis=1)

# %%
randomQuestions
# Out:
#                              id                                    title  \
# 85068  57321849b9d445190005e7dd                        Economy_of_Greece
# 52407  5726e2bf708984140094d4c3                                 Avicenna
# 2834   56cd8dbf62d2951400fa66f4   The_Legend_of_Zelda:_Twilight_Princess
# 51172  5727b0983acd2414000de9d7                              Switzerland
# 71514  573195b3e6313a140071d0d7                         Steven_Spielberg
# 47605  57288c223acd2414000dfad2                                  Myanmar
# 60406  5727c1593acd2414000debbb                          Exhibition_game
# 8061   56d632371c85041400946fe4                                      Dog
# 87020  5735ec17012e2f140011a0dd                                  Hunting
# 24100  5706a58a75f01819005e7cba                             Black_people
# 38589  5725d3b8ec44d21400f3d653                       Hellenistic_period
# 61347  5727f67d3acd2414000df0ef                       Gamal_Abdel_Nasser
# 35522  571a830810f8ca14003050c6                           Ashkenazi_Jews
# 52965  5726dbeadd62a815002e92ef                                  Nigeria
# 9143   573349f34776f41900660802      Financial_crisis_of_2007%E2%80%9308
# 82382  57320e760fdd8d15006c6724                                     Bird
# 59829  5728d223ff5b5019007da750                                  Detroit
# 57648  5727f310ff5b5019007d990d                        Gramophone_record
# 39666  57262801ec44d21400f3da74                                  Hokkien
# 67129  5729888b6aef051400154fb0                Neoclassical_architecture
# 44055  572779a2dd62a815002e9df8                   New_Haven,_Connecticut
# 25441  57061f8275f01819005e79b8                                      MP3
# 75273  572fea66b2c2fd14005685d4                          Antenna_(radio)
# 55232  5727862f5951b619008f8c4f                                   FA_Cup
# 7598   56db43dae7c41114004b4fdf                            American_Idol
# 62724  57280d3d4b864d1900164320                 Central_African_Republic
# 1942   56d3aab62ccc5a1400d82dec                          Frédéric_Chopin
# 66310  5728f1a1af94a219006a9e20                                  Samurai
# 9014   573374204776f41900660b05      Financial_crisis_of_2007%E2%80%9308
# 45484  572684a7dd62a815002e87f5                          Presbyterianism
# 42416  57267541708984140094c6cb                                   Greece
# 5987   56d1034017492d1400aab723                               Kanye_West
# 45642  57268bbfdd62a815002e88fc                                Thuringia
# 31786  570c5d12b3d812140066d18c                    John,_King_of_England
# 84590  5731cd690fdd8d15006c6556                            Protestantism
# 35131  57100ee5a58dae1900cd683a  Capital_punishment_in_the_United_States
# 1907   56cf4d7eaab44d1400b88f82                          Frédéric_Chopin
# 24067  5706602375f01819005e7b8b                             Black_people
# 74012  572ea0bdc246551400ce442f                                    Quran
# 39838  5725c74589a1e219009abe8e                               Montevideo
# 35255  5711165aa58dae1900cd6bf8            Nintendo_Entertainment_System
# 37793  57240b550ba9f01400d97b4c                           Queen_Victoria
# 29397  570b1e506b8089140040f733                       Gregorian_calendar
# 77691  572fe161947a6a140053cdb2                           Premier_League
# 26220  570727889e06ca38007e94a7                        Chihuahua_(state)
# 13090  56dfba0f231d4119001abd20                          Hunter-gatherer
# 78825  573445d3879d6814001ca45c                       Richmond,_Virginia
# 42977  57265f5df1498d1400e8dd93                   Professional_wrestling
# 84073  57321f30b9d445190005e823                 Religion_in_ancient_Rome
# 7372   56db2664e7c41114004b4e1b                            American_Idol
#
#                                                  context  \
# 85068  Greece has tended to lag behind its European U...
# 52407  Avicenna was a devout Muslim and sought to rec...
# 2834   The GameCube and Wii versions feature several ...
# 51172  In many places in Switzerland, household rubbi...
# 71514  In early 2009, Spielberg shot the first film i...
# 47605  The government has responded by imposing curfe...
# 60406  National Basketball Association teams play eig...
# 8061   A Colorado study found bites in children were ...
# 87020  Even as animal domestication became relatively...
# 24100  In 2008, the High Court in South Africa ruled ...
# 38589  Ptolemy, a somatophylax, one of the seven body...
# 61347  On 11 October 1951, the Wafd government abroga...
# 35522  They established communities throughout Centra...
# 52965  Nigeria regained democracy in 1999 when it ele...
# 9143   The term financial innovation refers to the on...
# 82382  All birds lay amniotic eggs with hard shells m...
# 59829  Detroit is one of 12 American metropolitan are...
# 57648  Ultimately, the New Orthophonic curve was disc...
# 39666  The term Hokkien (福建; hɔk˥˥kɪɛn˨˩) is itself a...
# 67129  From about 1800 a fresh influx of Greek archit...
# 44055  The city has many distinct neighborhoods. In a...
# 25441  As a doctoral student at Germany's University ...
# 75273  The standing wave forms with this desired patt...
# 55232  In the 51 years prior to the Empire Stadium op...
# 7598   The loss of viewers continued into season seve...
# 62724  In September 1940, during the Second World War...
# 1942   The British Library notes that "Chopin's works...
# 66310  From 1854, the samurai army and the navy were ...
# 9014   There is a direct relationship between decline...
# 45484  Presbyterianism first officially arrived in Co...
# 42416  The culture of Greece has evolved over thousan...
# 5987   West's breakthrough came a year later on Octob...
# 45642  The traditional energy supply of Thuringia is ...
# 31786  Neither John nor the rebel barons seriously at...
# 84590  The Scottish Reformation of 1560 decisively sh...
# 35131  In the 2010s, American jurisdictions have expe...
# 1907   Chopin's life was covered in a BBC TV document...
# 24067  American University economist George Ayittey a...
# 74012  The term also has closely related synonyms tha...
# 39838  Tourism accounts for much of Uruguay's economy...
# 35255  In the UK, Italy and Australia which share the...
# 37793  In the 1874 general election, Disraeli was ret...
# 29397  Prior to 1917, Turkey used the lunar Islamic c...
# 77691  The Premier League sells its television rights...
# 26220  President Juárez once again based his governme...
# 13090  The transition from hunting and gathering to a...
# 78825  Several of the city's large general museums ar...
# 42977  Illegal pinning methods include using the rope...
# 84073  In Rome, state cult to a living emperor acknow...
# 7372   Crystal Bowersox, who has Type-I diabetes, fel...
#
#                                                 question  \
# 85068  What has the been a massive increase in the nu...
# 52407                        What religion was Avicenna?
# 2834    What part of the Wii is employed to use weapons?
# 51172   What is the charge for recycling in Switzerland?
# 71514              Where did Adventures of Tintin debut?
# 47605  What happened in Rakhine in the summer of 2012...
# 60406        How many preseason games do NBA teams play?
# 8061   A dog scratch can lead to what medical condition?
# 87020                      Where is hunting still vital?
# 24100  Why did some Chinese citizens qualify for bene...
# 38589   When did Ptolemy declare himself King Ptolemy I?
# 61347      What treaty did the Wafd government abrogate?
# 35522  In the late 18th and 19th centuries, Jews who ...
# 52965                Who won the 1999 Nigerian election?
# 9143   What is the abbreviation for a form of credit ...
# 82382         What type of birds lay white or pale eggs?
# 59829  How many metropolitan areas boast teams from a...
# 57648           Who developed the New Orthophonic curve?
# 39666          Where are quanzhou and Zhangzhou located?
# 67129      What was the first Greek building in England?
# 44055  What area of New Haven comprises the area cent...
# 25441  Where did Bradenburg become an assistant profe...
# 75273  How are waves which are used in the ways discu...
# 55232  Where do the majority of FA cup finals take pl...
# 7598   Who was eliminated during the lowest rated sho...
# 62724  During what war did French officers setup head...
# 1942       When did Pabst record his Chopin performance?
# 66310  What nationality of engineers did Japan hire t...
# 9014   How much was home equity valued in the United ...
# 45484      In what city was the first Presbytery formed?
# 42416  The evolution of Grecian culture has evolved o...
# 5987   What song did Kanye record about his experienc...
# 45642                            What is Hohenwarte Dam?
# 31786                     John appealed to who for help?
# 84590  Whose regime made possible the Scottish Reform...
# 35131  The EU outlawed the export of products that co...
# 1907   What are the names of the two people that crea...
# 24067                                   Where were they?
# 74012  What name does the Quran use for itself that m...
# 39838       What accounts for much of Uruguay's economy?
# 35255  Which company distributed the NES to the UK, I...
# 37793  What year was the Public Worship Regulation Ac...
# 29397  What calendar did Turkey utilize for fiscal pu...
# 77691  How is the teleivsion revenue distributed in t...
# 26220  On March 25, 1866, a battle ensued where in Ch...
# 13090  What situation can cause food stresses that ma...
# 78825  How far away from the Virginia Center for Arch...
# 42977  How often are illegal pinning methods seen by ...
# 84073               What was the emperor's rule in Rome?
# 7372            What role does Warwick have on the show?
#
#                                                  answers  \
# 85068  {'text': ['a broadband connection'], 'answer_s...
# 52407         {'text': ['Muslim'], 'answer_start': [22]}
# 2834     {'text': ['Wii Remote'], 'answer_start': [171]}
# 51172          {'text': ['free'], 'answer_start': [357]}
# 71514  {'text': ['Brussels, Belgium'], 'answer_start'...
# 47605  {'text': ['On 10 June 2012, a state of emergen...
# 60406          {'text': ['eight'], 'answer_start': [43]}
# 8061    {'text': ['infections.'], 'answer_start': [396]}
# 87020  {'text': ['marginal climates'], 'answer_start'...
# 24100  {'text': ['they were also "disadvantaged" by r...
# 38589        {'text': ['305 BC'], 'answer_start': [180]}
# 61347  {'text': ['Anglo-Egyptian Treaty'], 'answer_st...
# 35522  {'text': ['a cultural reorientation'], 'answer...
# 52965  {'text': ['Olusegun Obasanjo'], 'answer_start'...
# 9143            {'text': ['CDS'], 'answer_start': [554]}
# 82382  {'text': ['Hole and burrow nesting species'], ...
# 59829             {'text': ['12'], 'answer_start': [18]}
# 57648     {'text': ['RCA Victor'], 'answer_start': [86]}
# 39666       {'text': ['Hokkien'], 'answer_start': [340]}
# 67129  {'text': ['garden temple at Hagley Hall (1758–...
# 44055       {'text': ['Downtown'], 'answer_start': [57]}
# 25441  {'text': ['Erlangen-Nuremberg'], 'answer_start...
# 75273  {'text': ['harmonically'], 'answer_start': [518]}
# 55232  {'text': ['predominantly in London, and mainly...
# 7598   {'text': ['Kristy Lee Cook'], 'answer_start': ...
# 62724  {'text': ['Second World War'], 'answer_start':...
# 1942           {'text': ['1895'], 'answer_start': [145]}
# 66310     {'text': ['tradition'], 'answer_start': [208]}
# 9014   {'text': ['$13 trillion'], 'answer_start': [588]}
# 45484  {'text': ['Philadelphia'], 'answer_start': [119]}
# 42416  {'text': ['thousands of years'], 'answer_start...
# 5987   {'text': ['"Through The Wire"'], 'answer_start...
# 45642  {'text': ['big pumped storage stations'], 'ans...
# 31786      {'text': ['Innocent'], 'answer_start': [418]}
# 84590  {'text': ['Mary of Guise'], 'answer_start': [6...
# 35131     {'text': ['execution'], 'answer_start': [328]}
# 1907   {'text': ['Angelo Bozzolini and Roberto Prosse...
# 24067         {'text': ['Sudan'], 'answer_start': [290]}
# 74012          {'text': ['waḥy'], 'answer_start': [440]}
# 39838         {'text': ['Tourism'], 'answer_start': [0]}
# 35255        {'text': ['Mattel'], 'answer_start': [214]}
# 37793          {'text': ['1874'], 'answer_start': [106]}
# 29397        {'text': ['Julian'], 'answer_start': [103]}
# 77691  {'text': ['The money is divided into three par...
# 26220  {'text': ['Plaza de Armas'], 'answer_start': [...
# 13090  {'text': ['environmental change'], 'answer_sta...
# 78825    {'text': ['two blocks'], 'answer_start': [426]}
# 42977  {'text': ['Such pins as these are rarely seen ...
# 84073  {'text': ['divinely approved'], 'answer_start'...
# 7372       {'text': ['producer'], 'answer_start': [322]}
#
#                                          gpt_3.5_answers
# 85068  {'text': ['a broadband connection'], 'answer_s...
# 52407        {'text': ['Muslim'], 'answer_start': [143]}
# 2834   {'text': ['motion sensors and built-in speaker...
# 51172          {'text': ['free'], 'answer_start': [186]}
# 71514  {'text': ['Brussels, Belgium'], 'answer_start'...
# 47605  On 10 June 2012, a state of emergency was decl...
# 60406          {'text': ['eight'], 'answer_start': [41]}
# 8061   {'text': ['serious infections'], 'answer_start...
# 87020        Hunting is still vital in marginal climates
# 24100  {'text': ['because they were also "disadvantag...
# 38589  The answer to the question is May referencing ...
# 61347  [{'text': 'the 1936 Anglo-Egyptian Treaty', 'a...
# 35522  {'text': ['a cultural reorientation'], 'answer...
# 52965  {'text': ['Olusegun Obasanjo'], 'answer_start'...
# 9143              [{'text': 'CDS', 'answer_start': 558}]
# 82382  {'text': ['Open nesters'], 'answer_start': [10...
# 59829             {'text': ['12'], 'answer_start': [20]}
# 57648  The answer should be {'text': ['R.C. Moyer'], ...
# 39666  {'text': ['Quanzhou and Zhangzhou'], 'answer_s...
# 67129  {'text': ["the garden temple at Hagley Hall"],...
# 44055  {'text': ['Downtown and Green'], 'answer_start...
# 25441  {'text': ['Erlangen-Nuremberg'], 'answer_start...
# 75273      {'text': 'standing wave', 'answer_start': 24}
# 55232  {'text': ['London', ' London'], 'answer_start'...
# 7598   {'text': ['Kristy Lee Cook'], 'answer_start': ...
# 62724  {'text': ['Second World War'], 'answer_start':...
# 1942           {'text': ['1895'], 'answer_start': [127]}
# 66310        {'text': ['French'], 'answer_start': [193]}
# 9014   {'text': ['$13 trillion'], 'answer_start': [351]}
# 45484   {'text': ['Philadelphia'], 'answer_start': [85]}
# 42416  {'text': ['thousands of years'], 'answer_start...
# 5987   {'text': ['Through The Wire'], 'answer_start':...
# 45642  {'text': ['Hohenwarte Dam'], 'answer_start': [...
# 31786      {'text': ['Innocent'], 'answer_start': [675]}
# 84590  {'text': ['the regime of the regent Mary of Gu...
# 35131  ?\n\n{'text': ['execution'], 'answer_start': [...
# 1907   {'text': ['Angelo Bozzolini', 'Roberto Prossed...
# 24067             In Sudan \n{'text': ['In Sudan'], 'ans
# 74012          {'text': ['waḥy'], 'answer_start': [295]}
# 39838         {'text': ['Tourism'], 'answer_start': [0]}
# 35255        {'text': ['Mattel'], 'answer_start': [115]}
# 37793           {'text': ['1874'], 'answer_start': [86]}
# 29397  {'text': ['the Julian calendar'], 'answer_star...
# 77691  {'text': ['The money is divided into three par...
# 26220  {'text': ['Plaza de Armas'], 'answer_start': [...
# 13090  {'text': ['environmental change'], 'answer_sta...
# 78825    {'text': ['Two blocks'], 'answer_start': [103]}
# 42977  {'text': ['Even if it is noticed, it is rare']...
# 84073  {'text': ['his rule as divinely approved and c...
# 7372   {'text': ["he show producer"], 'answer_start':...

# %%
randomQuestions.to_csv("SquadAnalysis2.csv", index=False)
