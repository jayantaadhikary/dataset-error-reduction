# %% [markdown]
# ## Using SQuAD dataset using Llama 2 model locally with help of Ollama

# %%
import requests
import json
import pandas as pd
from datasets import load_dataset

# %%
url = "http://localhost:11434/api/generate"

headers = {
    "Content-Type": "application/json"
}

# %%
dataset = load_dataset("squad")

# %%
df = pd.DataFrame(dataset["train"]).sample(n=10)

# %%
def getModelAnswer(row):
    context = row["context"]
    question = row["question"]
    
    data = {
        "model": "llama2",
        "prompt": f"Perform extractive question answering from the context and give me extact and specific answer.The answer should be in an array containing the answer and the start character index of the answer in format of {{'text': [], 'answer_start': []}}.\nContext: {context}\n\nQuestion: {question}\nAnswer:?",
        "stream": False
    }
    
    response = requests.post(url, headers=headers, data=json.dumps(data))
    
    if response.status_code == 200:
        response_text = response.text
        data = json.loads(response_text)
        actual_response = data["response"]
        return actual_response
    else:
        print("Error:", response.status_code, response.text)

# %%
df
# Out:
#                              id                             title  \
# 18467  56f6fe26711bf01900a448d7                   Classical_music
# 43691  572935dd3f37b3190047810f                           Germans
# 73195  573059852461fd1900a9cdb5                         The_Blitz
# 60039  5728c5dd3acd2414000dfe0e                            Sahara
# 22928  56fa5af68f12f3190063012e                              Wood
# 41951  5726cfd6dd62a815002e9105            Copyright_infringement
# 44316  5727ca06ff5b5019007d9558            New_Haven,_Connecticut
# 8277   56db0f17e7c41114004b4cea  2008_Summer_Olympics_torch_relay
# 74995  572f91c704bcaa1900d76a8d                    Modern_history
# 84137  573238630fdd8d15006c6862          Religion_in_ancient_Rome
#
#                                                  context  \
# 18467  Classical musicians continued to use many of i...
# 43691  The Germanic peoples during the Migrations Per...
# 73195  In the wake of the Coventry Blitz, there was w...
# 60039  The central Sahara is estimated to include fiv...
# 22928  Despite their collective name, not all woodwin...
# 41951  Copyright infringement disputes are usually re...
# 44316  After the American Revolutionary War broke out...
# 8277   \n France: The torch relay leg in Paris, held ...
# 74995  On December 7, 1941, Japan attacked the United...
# 84137  The Western emperor Gratian refused the office...
#
#                                                 question  \
# 18467               What did the Baroque trumpet become?
# 43691    What happened to the Huns after Attila's death?
# 73195             What did Morrison warn he couldn't do?
# 60039  What helps plants in order to get as much wate...
# 22928  What are woodwind instrument's reeds often mad...
# 41951  What can happen to people who commit copyright...
# 44316  In what year did the U.S. Congress afford Conn...
# 8277   About how many police were said to have protec...
# 74995          Where did Japan attack the United States?
# 84137  What flame did Theodosius extinguish to remove...
#
#                                                  answers  \
# 18467  {'text': ['the regular valved trumpet'], 'answ...
# 43691  {'text': ['either escaped into Asia, or otherw...
# 73195  {'text': ['that he could not counter the Commu...
# 60039  {'text': ['long roots that travel horizontally...
# 22928  {'text': ['Arundo donax'], 'answer_start': [147]}
# 41951  {'text': ['prosecuted via the criminal justice...
# 44316          {'text': ['1921'], 'answer_start': [918]}
# 8277         {'text': ['3,000'], 'answer_start': [1015]}
# 74995   {'text': ['Pearl Harbor'], 'answer_start': [57]}
# 84137   {'text': ['Sacred fire'], 'answer_start': [463]}
#
#                                           llama2_answers
# 18467  Sure! Based on the given context, the answer t...
# 43691  Context: The Germanic peoples during the Migra...
# 73195   {'text': ['What did Morrison warn he couldn't...
# 60039  Sure, I can help you with that! Based on the g...
# 22928  Context: Despite their collective name, not al...
# 41951  Context: Copyright infringement disputes are u...
# 44316   {'text': ['In what year did the U.S. Congress...
# 8277   Context: \nFrance: The torch relay leg in Pari...
# 74995  Context: On December 7, 1941, Japan attacked t...
# 84137  Context: The Western emperor Gratian refused t...

# %%
df['llama2_answers'] = df.apply(getModelAnswer, axis=1)

# %%
df
# Out:
#                              id                             title  \
# 18467  56f6fe26711bf01900a448d7                   Classical_music
# 43691  572935dd3f37b3190047810f                           Germans
# 73195  573059852461fd1900a9cdb5                         The_Blitz
# 60039  5728c5dd3acd2414000dfe0e                            Sahara
# 22928  56fa5af68f12f3190063012e                              Wood
# 41951  5726cfd6dd62a815002e9105            Copyright_infringement
# 44316  5727ca06ff5b5019007d9558            New_Haven,_Connecticut
# 8277   56db0f17e7c41114004b4cea  2008_Summer_Olympics_torch_relay
# 74995  572f91c704bcaa1900d76a8d                    Modern_history
# 84137  573238630fdd8d15006c6862          Religion_in_ancient_Rome
#
#                                                  context  \
# 18467  Classical musicians continued to use many of i...
# 43691  The Germanic peoples during the Migrations Per...
# 73195  In the wake of the Coventry Blitz, there was w...
# 60039  The central Sahara is estimated to include fiv...
# 22928  Despite their collective name, not all woodwin...
# 41951  Copyright infringement disputes are usually re...
# 44316  After the American Revolutionary War broke out...
# 8277   \n France: The torch relay leg in Paris, held ...
# 74995  On December 7, 1941, Japan attacked the United...
# 84137  The Western emperor Gratian refused the office...
#
#                                                 question  \
# 18467               What did the Baroque trumpet become?
# 43691    What happened to the Huns after Attila's death?
# 73195             What did Morrison warn he couldn't do?
# 60039  What helps plants in order to get as much wate...
# 22928  What are woodwind instrument's reeds often mad...
# 41951  What can happen to people who commit copyright...
# 44316  In what year did the U.S. Congress afford Conn...
# 8277   About how many police were said to have protec...
# 74995          Where did Japan attack the United States?
# 84137  What flame did Theodosius extinguish to remove...
#
#                                                  answers  \
# 18467  {'text': ['the regular valved trumpet'], 'answ...
# 43691  {'text': ['either escaped into Asia, or otherw...
# 73195  {'text': ['that he could not counter the Commu...
# 60039  {'text': ['long roots that travel horizontally...
# 22928  {'text': ['Arundo donax'], 'answer_start': [147]}
# 41951  {'text': ['prosecuted via the criminal justice...
# 44316          {'text': ['1921'], 'answer_start': [918]}
# 8277         {'text': ['3,000'], 'answer_start': [1015]}
# 74995   {'text': ['Pearl Harbor'], 'answer_start': [57]}
# 84137   {'text': ['Sacred fire'], 'answer_start': [463]}
#
#                                           llama2_answers
# 18467  Sure! Based on the given context, the answer t...
# 43691  The answer to your question is:\n\n{'text': ['...
# 73195  Morrison warned that he couldn't counter the C...
# 60039  Sure, I'd be happy to help you with that! Base...
# 22928  Sure! Based on the context you provided, the a...
# 41951  Based on the provided context, the answer to t...
# 44316  The answer to your question can be found in th...
# 8277   The answer to your question can be found in th...
# 74995  The answer to your question is:\n\n{'text': ['...
# 84137  The answer to your question is:\n\n{'text': ['...

# %%
df.to_csv("localSquad_llama2_ollama")
