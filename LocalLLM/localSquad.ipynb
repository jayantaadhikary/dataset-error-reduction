# %% [markdown]
# ## Using SQuAD dataset with LLM setup locally
# The model initially used is Mistral Instruct with 7 billion parameters which is compressed with Quantization 4

# %%
import openai
import pandas as pd
from datasets import load_dataset
import os

# %%
openai.api_base = "http://localhost:1234/v1"
openai.api_key = ""

# %%
# Testing the local Model 
test = openai.ChatCompletion.create(model="local-model", messages=[
    {"role": "system", "content": "You are Jay"},
    {"role": "user", "content": "Introduce yourself."}
  ])

# %%
print(test.choices[0].message)
# Out:
# {
#   "role": "assistant",
#   "content": "Hello, I am Jay. Nice to meet you! How can I help you today?"
# }

# %%
dataset = load_dataset("squad")

# %%
dataset.shape
# Out:
# {'train': (87599, 5), 'validation': (10570, 5)}

# %%
df = pd.DataFrame(dataset['train']).sample(n=10)

# %%
df
# Out:
#                              id                          title  \
# 9439   57336480d058e614000b5a00          Saint_Barth%C3%A9lemy
# 25899  5706ee379e06ca38007e921d                    Letter_case
# 35414  57112c66a58dae1900cd6cf2  Nintendo_Entertainment_System
# 57517  5727c5ccff5b5019007d94d7              Gramophone_record
# 70749  572ebe3c03f98919007569de                Muammar_Gaddafi
# 81716  5730f09fa5e9cc1400cdbb13               Russian_language
# 12278  56dfb587231d4119001abca2                            Pub
# 25372  5706e36d9e06ca38007e91e4                     Immunology
# 25371  5706e36d9e06ca38007e91e3                     Immunology
# 22096  56f903a79e9bad19000a07d3                      Near_East
#
#                                                  context  \
# 9439   Saint Barthélemy, a volcanic island fully enci...
# 25899  The convention followed by many British publis...
# 35414  A thriving market of unlicensed NES hardware c...
# 57517  The development of quadraphonic records was an...
# 70749  The Bovington signal course's director reporte...
# 81716  Among the first to study Russian dialects was ...
# 12278  Historically, pubs have been socially and cult...
# 25372  Maternal factors also play a role in the body’...
# 25371  Maternal factors also play a role in the body’...
# 22096  The Ministry of Foreign Affairs of the Republi...
#
#                                                 question  \
# 9439                   What is the capital of St. Barts?
# 25899  What is an alternative name for sentence-style...
# 35414  What was the name of the NES clone produced in...
# 57517  What did developments in quadraphonic recordin...
# 70749  When Gaddafi returned to Libya, how did he vie...
# 81716   Who made the first dialectal Russian dictionary?
# 12278  What are the windows of 1990s and later pubs o...
# 25372  At 6 to 9 months, an infant's immune system be...
# 25371  For how long do these antibodies have an effec...
# 22096  The Middle East, the Balkans and others are in...
#
#                                                  answers
# 9439       {'text': ['Gustavia'], 'answer_start': [181]}
# 25899  {'text': ['sentence case'], 'answer_start': [3...
# 35414         {'text': ['Dendy'], 'answer_start': [238]}
# 57517  {'text': ['later surround-sound systems'], 'an...
# 70749  {'text': ['while he travelled to England belie...
# 81716   {'text': ['Vladimir Dal'], 'answer_start': [90]}
# 12278   {'text': ['clear glass'], 'answer_start': [350]}
# 25372  {'text': ['glycoproteins'], 'answer_start': [1...
# 25371  {'text': ['up to 18 months'], 'answer_start': ...
# 22096  {'text': ['Republic of Turkey'], 'answer_start...

# %%
def getAnswerFromModel(row):
    question = row['question']
    context = row['context']
    
    response = openai.ChatCompletion.create(model="local-model", messages=[
        {"role": "system", "content": "Perform extractive Question Answering from the context. The answer should be in an array containing the answer and the start character index of the answer in format of {{'text': [], 'answer_start': []}}."},
        {"role": "user", "content": f"Context: {context}\n\nQuestion: {question}\nAnswer:?"}
    ])
    
    return response.choices[0].message.content

# %%
# testing a single row before trying out on the whole dataframe
testAnswer = getAnswerFromModel(df.loc[9439])

# %%
testAnswer
# Out:
# <OpenAIObject at 0x16dd2c650> JSON: {
#   "role": "assistant",
#   "content": "[{'text': ['Gustavia'], 'answer_start': [15]}]"
# }

# %%
df["Local Mistral Instruct 7B Q4_K_S"] = df.apply(getAnswerFromModel, axis=1)

# %%
df
# Out:
#                              id                          title  \
# 9439   57336480d058e614000b5a00          Saint_Barth%C3%A9lemy
# 25899  5706ee379e06ca38007e921d                    Letter_case
# 35414  57112c66a58dae1900cd6cf2  Nintendo_Entertainment_System
# 57517  5727c5ccff5b5019007d94d7              Gramophone_record
# 70749  572ebe3c03f98919007569de                Muammar_Gaddafi
# 81716  5730f09fa5e9cc1400cdbb13               Russian_language
# 12278  56dfb587231d4119001abca2                            Pub
# 25372  5706e36d9e06ca38007e91e4                     Immunology
# 25371  5706e36d9e06ca38007e91e3                     Immunology
# 22096  56f903a79e9bad19000a07d3                      Near_East
#
#                                                  context  \
# 9439   Saint Barthélemy, a volcanic island fully enci...
# 25899  The convention followed by many British publis...
# 35414  A thriving market of unlicensed NES hardware c...
# 57517  The development of quadraphonic records was an...
# 70749  The Bovington signal course's director reporte...
# 81716  Among the first to study Russian dialects was ...
# 12278  Historically, pubs have been socially and cult...
# 25372  Maternal factors also play a role in the body’...
# 25371  Maternal factors also play a role in the body’...
# 22096  The Ministry of Foreign Affairs of the Republi...
#
#                                                 question  \
# 9439                   What is the capital of St. Barts?
# 25899  What is an alternative name for sentence-style...
# 35414  What was the name of the NES clone produced in...
# 57517  What did developments in quadraphonic recordin...
# 70749  When Gaddafi returned to Libya, how did he vie...
# 81716   Who made the first dialectal Russian dictionary?
# 12278  What are the windows of 1990s and later pubs o...
# 25372  At 6 to 9 months, an infant's immune system be...
# 25371  For how long do these antibodies have an effec...
# 22096  The Middle East, the Balkans and others are in...
#
#                                                  answers  \
# 9439       {'text': ['Gustavia'], 'answer_start': [181]}
# 25899  {'text': ['sentence case'], 'answer_start': [3...
# 35414         {'text': ['Dendy'], 'answer_start': [238]}
# 57517  {'text': ['later surround-sound systems'], 'an...
# 70749  {'text': ['while he travelled to England belie...
# 81716   {'text': ['Vladimir Dal'], 'answer_start': [90]}
# 12278   {'text': ['clear glass'], 'answer_start': [350]}
# 25372  {'text': ['glycoproteins'], 'answer_start': [1...
# 25371  {'text': ['up to 18 months'], 'answer_start': ...
# 22096  {'text': ['Republic of Turkey'], 'answer_start...
#
#                         Local Mistral Instruct 7B Q4_K_S
# 9439      [{'text': ['Gustavia'], 'answer_start': [14]}]
# 25899  [{'text': ['sentence case'], 'answer_start': [...
# 35414  [{'text': ['Dendy'], 'answer_start': [16, 18, ...
# 57517  [{'text': ['They inspired later surround-sound...
# 70749  [{'text': ['He returned home “more confident a...
# 81716  [{'text': ['Vladimir Dal'], 'answer_start': [1...
# 12278  [{'text': ['clear glass'], 'answer_start': [16...
# 25372  [[{'text': ['an infant''s immune system begins...
# 25371  [{'text': ['These passively-acquired antibodie...
# 22096  Answer: ['The Ministry of Foreign Affairs of t...

# %%
df.to_csv("Squad_Local_MistralInstruct7BQ4.csv", index=False)
